# %% [markdown]
# # Dealing with Rows and Columns in Pandas DataFrame

# %% [markdown]
# # Dealing with Columns

# %%
import pandas as pd

# %%
data = {'Name': ['Rahul','minato','naruto','kakashi'],
         'Age': ['16','24','17','20'],
         'Address':['leaf village','leaf village','leaf village','leaf village'],
         'Qualification' : ['gennin','hokage','genin','jonin']
       }

# %%
df = pd.DataFrame(data)
print(df[["Name","Qualification"]])
# Out:
#       Name Qualification
# 0    Rahul        gennin
# 1   minato        hokage
# 2   naruto         genin
# 3  kakashi         jonin

# %%
skills = ['Rassengan','shadowclone','ftg','chidori']
df['Skills'] = skills

# %%
print(df)
# Out:
#       Name Age       Address Qualification       Skills
# 0    Rahul  16  leaf village        gennin    Rassengan
# 1   minato  24  leaf village        hokage  shadowclone
# 2   naruto  17  leaf village         genin          ftg
# 3  kakashi  20  leaf village         jonin      chidori

# %%
df.drop(["Age","Address"],axis =1,inplace = True)
df
# Out:
#       Name Qualification       Skills
# 0    Rahul        gennin    Rassengan
# 1   minato        hokage  shadowclone
# 2   naruto         genin          ftg
# 3  kakashi         jonin      chidori

# %% [markdown]
# The axis=1 parameter specifies that columns

# %% [markdown]
# # Dealing with Rows:

# %% [raw]
# Pandas provide a unique method to retrieve rows from a Data frame.
#
# DataFrame.loc[]
#
# method is used to retrieve rows from Pandas DataFrame. Rows can also be selected by passing integer location to an
#
# iloc[]

# %%
data =pd.read_csv("C:/Users/rahul/Downloads/nba.csv",index_col ="Name")
data.head()
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#                          College     Salary
# Name
# Avery Bradley              Texas  7730337.0
# Jae Crowder            Marquette  6796117.0
# John Holland   Boston University        NaN
# R.J. Hunter        Georgia State  1148640.0
# Jonas Jerebko                NaN  5000000.0

# %%
# retrieving row by loc method
first = data.loc["Avery Bradley"]
second = data.loc["R.J. Hunter"]
print(first, "\n\n\n", second)
# Out:
# Team        Boston Celtics
# Number                 0.0
# Position                PG
# Age                   25.0
# Height                 6-2
# Weight               180.0
# College              Texas
# Salary           7730337.0
# Name: Avery Bradley, dtype: object
#
#
#  Team        Boston Celtics
# Number                28.0
# Position                SG
# Age                   22.0
# Height                 6-5
# Weight               185.0
# College      Georgia State
# Salary           1148640.0
# Name: R.J. Hunter, dtype: object

# %% [markdown]
# # Python | Pandas Extracting rows using .loc[]

# %% [markdown]
# Multiple parameters

# %%
row=  data.loc[["Jae Crowder","John Holland"]]
row
# Out:
#                         Team  Number Position   Age Height  Weight  \
# Name
# Jae Crowder   Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#                         College     Salary
# Name
# Jae Crowder           Marquette  6796117.0
# John Holland  Boston University        NaN

# %%
type(row)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Extracting rows between two index labels

# %%
rows = data.loc["Avery Bradley":"Jonas Jerebko"]
rows
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#                          College     Salary
# Name
# Avery Bradley              Texas  7730337.0
# Jae Crowder            Marquette  6796117.0
# John Holland   Boston University        NaN
# R.J. Hunter        Georgia State  1148640.0
# Jonas Jerebko                NaN  5000000.0

# %%
data =pd.read_csv("C:/Users/rahul/Downloads/nba.csv",index_col ="Team")
data.head()
# Out:
#                          Name  Number Position   Age Height  Weight  \
# Team
# Boston Celtics  Avery Bradley     0.0       PG  25.0    6-2   180.0
# Boston Celtics    Jae Crowder    99.0       SF  25.0    6-6   235.0
# Boston Celtics   John Holland    30.0       SG  27.0    6-5   205.0
# Boston Celtics    R.J. Hunter    28.0       SG  22.0    6-5   185.0
# Boston Celtics  Jonas Jerebko     8.0       PF  29.0   6-10   231.0
#
#                           College     Salary
# Team
# Boston Celtics              Texas  7730337.0
# Boston Celtics          Marquette  6796117.0
# Boston Celtics  Boston University        NaN
# Boston Celtics      Georgia State  1148640.0
# Boston Celtics                NaN  5000000.0

# %% [markdown]
# # Extracting multiple rows with same index

# %%
rows = data.loc["Utah Jazz"]
rows
# Out:
#                      Name  Number Position   Age Height  Weight       College  \
# Team
# Utah Jazz   Trevor Booker    33.0       PF  28.0    6-8   228.0       Clemson
# Utah Jazz      Trey Burke     3.0       PG  23.0    6-1   191.0      Michigan
# Utah Jazz      Alec Burks    10.0       SG  24.0    6-6   214.0      Colorado
# Utah Jazz      Dante Exum    11.0       PG  20.0    6-6   190.0           NaN
# Utah Jazz  Derrick Favors    15.0       PF  24.0   6-10   265.0  Georgia Tech
# Utah Jazz     Rudy Gobert    27.0        C  23.0    7-1   245.0           NaN
# Utah Jazz  Gordon Hayward    20.0       SF  26.0    6-8   226.0        Butler
# Utah Jazz     Rodney Hood     5.0       SG  23.0    6-8   206.0          Duke
# Utah Jazz      Joe Ingles     2.0       SF  28.0    6-8   226.0           NaN
# Utah Jazz   Chris Johnson    23.0       SF  26.0    6-6   206.0        Dayton
# Utah Jazz      Trey Lyles    41.0       PF  20.0   6-10   234.0      Kentucky
# ...

# %% [markdown]
# # Extracting rows using Pandas .iloc[] in Python

# %% [markdown]
# In the Python Pandas library, .iloc[] is an indexer used for integer-location-based indexing of data in a DataFrame. It allows users to select specific rows and columns by providing integer indices, making it a valuable tool for data manipulation and extraction based on numerical positions within the DataFrame.

# %%
df =pd.read_csv("C:/Users/rahul/Downloads/nba.csv")
df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
r1 = df.loc[3]
r2 = df.iloc[3]

# %%
r1 ==r2
# Out:
# Name        True
# Team        True
# Number      True
# Position    True
# Age         True
# Height      True
# Weight      True
# College     True
# Salary      True
# Name: 3, dtype: bool

# %% [markdown]
# # Selecting Multiple Rows using Pandas .iloc[] in Python

# %%
r1=df.iloc[[ 4,5,6,7]]
r2=df.iloc[4:8]

# %%
r1 == r2
# Out:
#    Name  Team  Number  Position   Age  Height  Weight  College  Salary
# 4  True  True    True      True  True    True    True    False    True
# 5  True  True    True      True  True    True    True    False    True
# 6  True  True    True      True  True    True    True     True    True
# 7  True  True    True      True  True    True    True     True    True

# %% [markdown]
# # Indexing and Selecting Data with Pandas

# %% [markdown]
# Indexing in Pandas :
# Indexing in pandas means simply selecting particular rows and columns of data from a DataFrame. Indexing could mean selecting all the rows and some of the columns, some of the rows and all of the columns, or some of each of the rows and columns. Indexing can also be known as Subset Selection.

# %% [markdown]
# # Indexing a Dataframe using indexing operator [] :

# %%
data = pd.read_csv("C:/Users/rahul/Downloads/nba.csv",index_col = "Name")

# %%
data.head()
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#                          College     Salary
# Name
# Avery Bradley              Texas  7730337.0
# Jae Crowder            Marquette  6796117.0
# John Holland   Boston University        NaN
# R.J. Hunter        Georgia State  1148640.0
# Jonas Jerebko                NaN  5000000.0

# %% [markdown]
# # Selecting a single columns

# %%
first = data["Age"]
first.head()
# Out:
# Name
# Avery Bradley    25.0
# Jae Crowder      25.0
# John Holland     27.0
# R.J. Hunter      22.0
# Jonas Jerebko    29.0
# Name: Age, dtype: float64

# %% [markdown]
# # Selecting a multipe columns

# %%
second = data[["Team","Number","Position"]]
second.head()
# Out:
#                          Team  Number Position
# Name
# Avery Bradley  Boston Celtics     0.0       PG
# Jae Crowder    Boston Celtics    99.0       SF
# John Holland   Boston Celtics    30.0       SG
# R.J. Hunter    Boston Celtics    28.0       SG
# Jonas Jerebko  Boston Celtics     8.0       PF

# %% [markdown]
# # Selecting two rows and three columns

# %%
sel = data.loc[["Avery Bradley","Jae Crowder"],["Team","Number","Position"]]
sel
# Out:
#                          Team  Number Position
# Name
# Avery Bradley  Boston Celtics     0.0       PG
# Jae Crowder    Boston Celtics    99.0       SF

# %% [markdown]
# # Selecting all of the rows and some columns

# %%
sel = data.loc[:,["Team","Number","Position"]]
sel.tail()
# Out:
#                    Team  Number Position
# Name
# Shelvin Mack  Utah Jazz     8.0       PG
# Raul Neto     Utah Jazz    25.0       PG
# Tibor Pleiss  Utah Jazz    21.0        C
# Jeff Withey   Utah Jazz    24.0        C
# NaN                 NaN     NaN      NaN

# %% [markdown]
# # Indexing a DataFrame using .iloc[ ] :
# This function allows us to retrieve rows and columns by position. In order to do that, we’ll need to specify the positions of the rows that we want, and the positions of the columns that we want as well. The df.iloc indexer is very similar to df.loc but only uses integer locations to make its selections.

# %%
data.iloc[4]
# Out:
# Team        Boston Celtics
# Number                 8.0
# Position                PF
# Age                   29.0
# Height                6-10
# Weight               231.0
# College                NaN
# Salary           5000000.0
# Name: Jonas Jerebko, dtype: object

# %% [markdown]
# # Selecting two rows and two columns

# %%
data.iloc[[1,2],[1,2]]# printing 1st row and 1st column
# Out:
#               Number Position
# Name
# Jae Crowder     99.0       SF
# John Holland    30.0       SG

# %% [markdown]
# # Selecting all the rows and a some columns

# %%
data.iloc[:,[1,2]]
# Out:
#                Number Position
# Name
# Avery Bradley     0.0       PG
# Jae Crowder      99.0       SF
# John Holland     30.0       SG
# R.J. Hunter      28.0       SG
# Jonas Jerebko     8.0       PF
# ...               ...      ...
# Shelvin Mack      8.0       PG
# Raul Neto        25.0       PG
# Tibor Pleiss     21.0        C
# Jeff Withey      24.0        C
# NaN               NaN      NaN
#
# [458 rows x 2 columns]

# %% [markdown]
# # Boolean Indexing in Pandas

# %% [markdown]
# In boolean indexing, we will select subsets of data based on the actual values of the data in the DataFrame and not on their row/column labels or integer locations. In boolean indexing, we use a boolean vector to filter the data.

# %% [markdown]
# # Masking data based on column value:

# %%
dict = {'name':["aparna", "pankaj", "sudhir", "Geeku"],
        'degree': ["BCA", "BCA", "M.Tech", "BCA"],
        'score':[90, 40, 80, 98]}
 
# creating a dataframe 
df = pd.DataFrame(dict)
  
# using a comparison operator for filtering of data
print(df['degree'] == 'BCA')
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# Name: degree, dtype: bool

# %%
# making data frame from csv file
data = pd.read_csv("C:/Users/rahul/Downloads/nba.csv", index_col ="Name")
  
# using greater than operator for filtering of data
print(data['Age'] > 25)
# Out:
# Name
# Avery Bradley    False
# Jae Crowder      False
# John Holland      True
# R.J. Hunter      False
# Jonas Jerebko     True
#                  ...
# Shelvin Mack      True
# Raul Neto        False
# Tibor Pleiss      True
# Jeff Withey       True
# NaN              False
# Name: Age, Length: 458, dtype: bool
